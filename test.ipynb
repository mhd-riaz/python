# %%
2**3
# Out:
# 8

# %%
import math

# %%
math.pow(2,3)
# Out:
# 8.0

# %%
pow(2,3)
# Out:
# 8

# %%
pow(2.1,1)
# Out:
# 2.1

# %%
f1 = open("new_file.txt", 'w')
print("file written at file", file=f1)
f1.close()
