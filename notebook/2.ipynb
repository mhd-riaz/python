# %% [markdown]
# # Inputs

# %% [markdown]
# ## QST 1
# Using input function, create a list base on the input provided by user and get inputs for the list too

# %%
n = int(input("enter list length: "))
arr = []
for i in range(n):
    val=int(input("enter input for index " + str(i) + " : "))
    arr.append(val)

print(arr)
# Out:
# [3, 3, 3]

# %% [markdown]
# using while loop

# %%
n = int(input("enter list length: "))
arr = []
while n>0:
    val = int(input("enter input for index " + str(n) + " : "))
    arr.append(val)
    n=n-1
print(arr)

# %% [markdown]
# using list comprehension

# %%
n,arr = int(input("enter list length: ")),[]
[arr.append(int(input("enter input for index " + str(i) + " : "))) for i in range(n)]
print(arr)

# %% [markdown]
# **Efficient way**:
# Often in competitive programming or data processing, it's more efficient to ask the user for all numbers at once (separated by spaces) rather than hitting the input() syscall n times.

# %%
# Input: 10 20 30 40
arr = list(map(int, input("Enter all numbers separated by space: ").split()))

# %% [markdown]
# ---

# %% [markdown]
# # While

# %% [markdown]
# ## QST 2
# Sum of 10 number

# %%
n = 10
sum = 0
while n >0:
    sum+=n
    n=n-1
print("sum: ",sum)

# %% [markdown]
# Usage of while

# %%
num = int(input("Enter the num, (0 to stop)"))
while num != 0:
    print("Entered number is: ", num)
    num=int(input("Enter the num, (0 to stop)"))

# %% [markdown]
# Usage of while with break

# %%
num = int(input("Enter the num, (0 to stop)"))
while True:
    print("Entered number is: ", num)
    num=int(input("Enter the num, (0 to stop)"))
    if num==0:
        break

# %% [markdown]
# ---

# %% [markdown]
# # Tuple

# %%
t1 = (1, 2, "asdf", [55, 66, 77], [33, 44])
len(t1)
t1[3][0] # 55 
# BUT
t1[3][0] = 56
t1 # (1, 2, 3, [56, 66, 77], [33, 44]), NOTE the change in value, coz list can be updated
t1[3].append(77)

# t1[2] = "a" # NOTE not allowed

# %%
t = (1, 2, 3)
t = t*2
t

# %% [markdown]
# ---

# %% [markdown]
# # Set

# %%
mySet = set((1,2,1, True,0, False))
mySet #

# %%
s = "madam"
set(s)

# %%
d = {1:"abc", 2: "efg"}
type(d)
d.keys()

# %%
s = "abc"*2
set(s)

# %%
s = set(['abc', 'abc'])
s

# %%
s = set([1,2,3,4,1,2])
s1 = {2,4}
s-s1

# %%
s&s1

# %% [markdown]
# ## QST 4
#
# ```py
# s1 = set(range(5)); print(s1)
# s2 = set(range(0,10,2)); print(s2)
# s3 = s1 - s2; print(s3)
# s4 = s2 - s1; print(s4)
# s5 = s3 & s4; print(s5)
# s6 = s3 | s4; print(s6)
# ```

# %%
s1 = set(range(5)); print(s1)
s2 = set(range(0,10,2)); print(s2)
s3 = s1 - s2; print(s3)
s4 = s2 - s1; print(s4)
s5 = s3 & s4; print(s5)
s6 = s3 | s4; print(s6)

# %%
s = set([1,2,3,4,1,2])
s1 = {2,4}

print(s.issuperset(s1)) # True
s1.issuperset(s) # False

# %% [markdown]
# ---

# %% [markdown]
# # List comprehension

# %%
# %%time

# unoptimized function
square = []
for i in range(10):
    if i%2==0:
        square.append(i*i)
print(square)

# %%
# %%time

square = [i*i for i in range(10) if i%2==0 ]
print(square)

# %% [markdown]
# # QST 5
#
# ```py
# name = ["Rama", "sita", "lakshmana", "john"]
# ```
#
# Get me those name that has only 'a' in it

# %%
names = ["Rama", "sita", "lakshmana", "john"]
word = [i for i in names if "a" in i]
print(word)

# %%
# 5.b > print the last character using list comprehension

lastChar = [ i[-1] for i in names ]
print(lastChar)

# %%
# 5.c > print name that have more than 4 characters using list comprehension

lenGreaterThanFour = [i for i in names if len(i)>4]
print(lenGreaterThanFour)

# %%
# 5.d > print word and its length using list comprehension

wordCount = [{i,len(i)} for i in names]
print(wordCount)

# %%
# 5.e > convert each word to upper case using list comprehension

upper = [str.upper(i) for i in names]
print(upper)

# %%
# 5.f > cover name only if it has length > 4 using list comprehension

upperGrtThan4 = [str.upper(i) for i in names if len(i)>4]
print(upperGrtThan4)

# %%
# 5.g > give common elements in both list using list comprehension

l = [1,2,3,4]
l1=[3,4,5,6]

common = [i for i in l1 if i in l]
print(common)

# %% [markdown]
# ---
#
# # Functions

# %%
def f1(x, a =[]):
    a.append(x)
    print(a)
f1(100)
f1(200)
z = [30, 40]
f1(50, z)
f1(600)
# Out:
# [100]
# [100, 200]
# [30, 40, 50]
# [100, 200, 600]

# %%
def f1(x):
    x = 20
a=10
f1(a)
print(a)

# %% [markdown]
# k = lambda a,b:a+b
# print(k(10,20))

# %%
k = lambda a,b:a+b
print(k(10,20))
# Out:
# 30

# %%
l = ["abc", "abcd", "abcde"]
res = []
def f1(l):
    for i in l:
        res.append(len(i))
    print(res)

f1(l)
# Out:
# [3, 4, 5]

# %%
# using map
print(list(map(len, l)))
print(list(map(str.upper, l)))
# Out:
# [3, 4, 5]
# ['ABC', 'ABCD', 'ABCDE']

# %%
# using map
l = [2,3,4,5]
def sq(i):
    return i*i
print(list(map(sq, l)))
# Out:
# [4, 9, 16, 25]

# %%
# using lambda
print(list(map( lambda x:x*x, l)))
# Out:
# [4, 9, 16, 25]

# %%
l = ["apple", "mango", "banana", "pear"]
print(list(filter(lambda x: 'o' in x, l)))
# Out:
# ['mango']

# %% [markdown]
# QST 6:
# give those fruits whose len is > 4

# %%
print(list(filter(lambda x:len(x)>4, l)))
# Out:
# ['apple', 'mango', 'banana']

# %%
print(list(map(str.upper ,filter(lambda x:len(x)>4, l))))
# Out:
# ['APPLE', 'MANGO', 'BANANA']

# %%
# reduce function
import functools as f


def f1(x,y):
    return x+y

l = [1,2,3,4,5]
print("using sum: ",sum(l))
print("using custom: ",f.reduce(f1,l))
# Out:
# using sum:  15
# using custom:  15

# %% [markdown]
# QST 7: given a name, pick up just first character

# %%
name = "Mohamed Riaz Hello World"

def f1(x,y):
    return str(x+y[0])

# print(f.reduce(f1, name.split(" ")))
print(f.reduce(lambda x,y:x+y[0], name.split(" ")," "))
# Out:
# MRHW

# %% [markdown]
# Factorial
#
# $$n! = n \times (n-1) \times (n-2) \times \dots \times 1$$

# %%
import math
print(math.factorial(5))
# Out:
# 120

# %%
def factorial(x):
    if x == 0:
        return 1
    res = x * factorial(x-1)
    return res

factorial(5)
# Out:
# 120

# %%
# summation two numbers using recursion
def ss(x,y):
    if y == 0:
        return x
    return ss(x+1, y-1)

print(ss(5,6))
# Out:
# 11
